# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/huawei
# Out:
# /content/drive/.shortcut-targets-by-id/1vmHHALcLjRq0GSmKayjw7O7CeLOATRhO/huawei

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec

mat = scipy.io.loadmat('BlackBoxData_200')
x = np.array(mat['x']).reshape(-1,1)/2**15
d = np.array(mat['y']).reshape(-1,1)/2**15


#ORD = np.random.randit(5, 9, 1)

#dl = [-3, -2, -1, 0, 1, 2, 3, -1,  1]
#ds = [-3, -2, -1, 0, 1, 2, 3,  1, -1]

for i in range(100):

  ORD = int(np.random.randint(7, 9, 1))
  print('ORD = ', ORD)
  
  dl = np.random.randint(-3, 3, 11)
  ds = np.random.randint(-3, 3, 11)


  print('dl = ', dl)
  print('ds = ', ds)

  mem = len(dl)

  U = np.zeros((len(d), mem*(ORD+1)), dtype = complex)


  ind = np.arange(3,len(d)-3)
  for k in ind:
      for m in range(mem):
          for p in range(ORD+1):
              U[k, p+m*(ORD+1) ] = x[k - dl[m]] * abs(x[k - ds[m]])**(2*p)
        
        
# LS estimation
     
  Rxx = np.matmul(np.conj(U.T), U)
  rdy = np.matmul(np.conj(U.T), d)

  w = np.matmul(np.linalg.pinv(Rxx),rdy)

  z = np.matmul(U, w)

#NMSE = 10*log10((d.norm(dim=1)**2).sum()/(x.norm(dim=1)**2).sum())
  NMSE = 10*np.log10(np.linalg.norm(d-z)**2/np.linalg.norm(x)**2)
  print('NMSE = ',NMSE)

  #plt.figure()
  #plt.psd(x, NFFT = 2048)
  #plt.psd(d, NFFT = 2048)
  #plt.psd(z, NFFT = 2048)
  #plt.psd(d-z, NFFT = 2048)
  #plt.grid(True)
  #plt.show()
        

  #plt.figure()
  #plt.plot(abs(x))
  #plt.plot(abs(d))
  #plt.plot(abs(z))
  #plt.plot(abs(d-z))
# Out:
# ORD =  8
# dl =  [-3  2 -1 -1 -2  1  0 -1  2 -1 -2]
# ds =  [ 0  2 -1  0  0  2 -2 -1 -2  2  1]
# NMSE =  -23.294196411133562
# ORD =  8
# dl =  [-2  2 -2  1  1  2  0  2 -2  0 -1]
# ds =  [-2  0  0  2  2  1 -2 -1  2  0  0]
# NMSE =  -26.74579682654642
# ORD =  8
# dl =  [ 2  0 -1 -2  0  1  0  1 -2 -2  1]
# ds =  [-3  1  2 -2  1 -3 -2  0  1  0 -3]
# NMSE =  -23.2339508976759
# ORD =  7
# dl =  [ 1 -3 -1  2 -3  0  0 -1  1  2 -1]
# ds =  [ 0 -3  0  1 -1 -2  2  0 -1 -2  2]
# NMSE =  -25.50775986399875
# ORD =  8
# dl =  [ 2  2  2  1 -3  1  0 -2 -1  0  1]
# ds =  [-2 -1  1  2  1  2  2  0  2 -2 -3]
# NMSE =  -18.59276054316944
# ORD =  7
# dl =  [-1 -1 -2 -1  0 -1  0 -2  1  0 -2]
# ds =  [ 2 -3  0 -2 -2  1 -3  1  1 -2 -3]
# NMSE =  -19.7463720448367
# ORD =  7
# dl =  [-3 -3  0  0  2  2 -3  0  1 -1  0]
# ds =  [-1  0 -1  0 -2  1 -1  0 -1 -1  2]
# ---------------------------------------------------------------------------
# ...
